# %%
import pandas as pd 
df = pd.Series([2,3,4,5,6], index = ["a","b","c","d","e"])
df
# Out:
# a    2
# b    3
# c    4
# d    5
# e    6
# dtype: int64

# %%
data1 = {
    "Name" : ["Mohit","Suhan","Priya","Gunjan"],
    "Age"  :  [23,41,12,35,],
    "Hobby" : ["Cricket","Football","Chess","Ludo"]
}

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#      Name  Age     Hobby
# 0   Mohit   23   Cricket
# 1   Suhan   41  Football
# 2   Priya   12     Chess
# 3  Gunjan   35      Ludo

# %%
data2 = [["Ajay",25,"Cricketr",1958],
          ["Mehul",54,"Chessplayer",1999]]
df2 = pd.DataFrame(data2,columns = ["Name","Age","Profession","Birth_year"])
df2
# Out:
#     Name  Age   Profession  Birth_year
# 0   Ajay   25     Cricketr        1958
# 1  Mehul   54  Chessplayer        1999

# %%
df = pd.DataFrame({
"Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
"Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
"Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
"Salary": [85, 90, 78, 85, 92, 88, 75, 80],
"Age": [23, 25, 30, 22, 28, 26, 21, 27],
"JoinDate": pd.to_datetime([
"2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
"2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
])
})
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
df.groupby("Department")["Salary"].agg(max_salary = "min")
# Out:
#             max_salary
# Department
# HR                  85
# IT                  78
# Marketing           88
# Sales               75

# %%
df.groupby("Team")["Salary"].agg(["mean", "max", "min"])
# Out:
#       mean  max  min
# Team
# A     87.5   90   85
# B     81.5   85   78
# C     90.0   92   88
# D     77.5   80   75

# %%
df["Team Avg"] = df.groupby("Team")["Salary"].transform("mean")
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Team Avg
# 0         HR    A      M      85   23 2020-01-10      87.5
# 1         HR    A      F      90   25 2020-02-15      87.5
# 2         IT    B      M      78   30 2021-03-20      81.5
# 3         IT    B      F      85   22 2021-04-10      81.5
# 4  Marketing    C      M      92   28 2020-05-30      90.0
# 5  Marketing    C      F      88   26 2020-06-25      90.0
# 6      Sales    D      M      75   21 2021-07-15      77.5
# 7      Sales    D      F      80   27 2021-08-01      77.5

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"]})
pd.concat([df1, df2])
# Out:
#       Name
# 0    Alice
# 1      Bob
# 0  Charlie
# 1    David

# %%
df1 = pd.DataFrame({"ID": [1, 2]})
df2 = pd.DataFrame({"Score": [90, 80]})
pd.concat([df1, df2], axis=1)
# Out:
#    ID  Score
# 0   1     90
# 1   2     80
