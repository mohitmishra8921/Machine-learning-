# %%
import pandas as pd

df = pd.read_csv('housing.csv')

# Clean column names (strip spaces, make lowercase to match easily)
df.columns = df.columns.str.strip()

# Define your desired columns (checking common variations)
desired_columns = [
    "Households", "Population", "House_median_age", "Total_rooms", 
    "Total_bedrooms", "Longitude", "Latitude", "Median_income", 
    "Median_house_value", "Ocean_proximity"
]


# This maps columns case-insensitively so it won't crash
column_mapping = {col.upper(): col for col in df.columns}
matched_cols = []
for col in desired_columns:
    # Look for exact or lowercase match
    if col in df.columns:
        matched_cols.append(col)
    elif col.upper() in column_mapping:
        matched_cols.append(column_mapping[col.upper()])

housing_data = df[matched_cols].copy()
housing_data
# Out:
#        households  population  total_rooms  total_bedrooms  longitude  \
# 0           126.0       322.0        880.0           129.0    -122.23
# 1          1138.0      2401.0       7099.0          1106.0    -122.22
# 2           177.0       496.0       1467.0           190.0    -122.24
# 3           219.0       558.0       1274.0           235.0    -122.25
# 4           259.0       565.0       1627.0           280.0    -122.25
# ...           ...         ...          ...             ...        ...
# 20635       330.0       845.0       1665.0           374.0    -121.09
# 20636       114.0       356.0        697.0           150.0    -121.21
# 20637       433.0      1007.0       2254.0           485.0    -121.22
# 20638       349.0       741.0       1860.0           409.0    -121.32
# 20639       530.0      1387.0       2785.0           616.0    -121.24
#
#        latitude  median_income  median_house_value ocean_proximity
# ...

# %%
# Out:
# ['Households',
#  'Population',
#  'House_median_age',
#  'Total_rooms',
#  'Total_bedrooms',
#  'Longitude',
#  'Latitude',
#  'Median_income',
#  'Median_house_value',
#  'Ocean_proximity']

# %%
 housing_data.columns = [
    "Households", "Population",  "Total_rooms", 
    "Total_bedrooms", "Longitude", "Latitude", "Median_income", 
    "Median_house_value", "Ocean_proximity"
].copy()
housing_data
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0           126.0       322.0        880.0           129.0    -122.23
# 1          1138.0      2401.0       7099.0          1106.0    -122.22
# 2           177.0       496.0       1467.0           190.0    -122.24
# 3           219.0       558.0       1274.0           235.0    -122.25
# 4           259.0       565.0       1627.0           280.0    -122.25
# ...           ...         ...          ...             ...        ...
# 20635       330.0       845.0       1665.0           374.0    -121.09
# 20636       114.0       356.0        697.0           150.0    -121.21
# 20637       433.0      1007.0       2254.0           485.0    -121.22
# 20638       349.0       741.0       1860.0           409.0    -121.32
# 20639       530.0      1387.0       2785.0           616.0    -121.24
#
#        Latitude  Median_income  Median_house_value Ocean_proximity
# ...

# %%
housing_data
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0           126.0       322.0        880.0           129.0    -122.23
# 1          1138.0      2401.0       7099.0          1106.0    -122.22
# 2           177.0       496.0       1467.0           190.0    -122.24
# 3           219.0       558.0       1274.0           235.0    -122.25
# 4           259.0       565.0       1627.0           280.0    -122.25
# ...           ...         ...          ...             ...        ...
# 20635       330.0       845.0       1665.0           374.0    -121.09
# 20636       114.0       356.0        697.0           150.0    -121.21
# 20637       433.0      1007.0       2254.0           485.0    -121.22
# 20638       349.0       741.0       1860.0           409.0    -121.32
# 20639       530.0      1387.0       2785.0           616.0    -121.24
#
#        Latitude  Median_income  Median_house_value Ocean_proximity
# ...

# %%
df2 = housing_data.sort_values(["Households","Median_income"],ascending=True).copy()
df2
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 16171         1.0        13.0          8.0             1.0    -122.50
# 12286         2.0         8.0          6.0             2.0    -116.95
# 3126          2.0         6.0          2.0             2.0    -117.79
# 2511          2.0        28.0         49.0             7.0    -119.54
# 12458         3.0         5.0         18.0             3.0    -114.62
# ...           ...         ...          ...             ...        ...
# 8985       4930.0      7431.0      18132.0          5419.0    -118.44
# 6057       5050.0     15507.0      32054.0          5290.0    -117.78
# 10309      5189.0     16122.0      37937.0          5471.0    -117.74
# 13139      5358.0     16305.0      39320.0          6210.0    -121.44
# 9880       6082.0     28566.0      32627.0          6445.0    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity
# ...

# %%
df2.reset_index(drop=True,inplace= True)
df2
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0             1.0        13.0          8.0             1.0    -122.50
# 1             2.0         8.0          6.0             2.0    -116.95
# 2             2.0         6.0          2.0             2.0    -117.79
# 3             2.0        28.0         49.0             7.0    -119.54
# 4             3.0         5.0         18.0             3.0    -114.62
# ...           ...         ...          ...             ...        ...
# 20635      4930.0      7431.0      18132.0          5419.0    -118.44
# 20636      5050.0     15507.0      32054.0          5290.0    -117.78
# 20637      5189.0     16122.0      37937.0          5471.0    -117.74
# 20638      5358.0     16305.0      39320.0          6210.0    -121.44
# 20639      6082.0     28566.0      32627.0          6445.0    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity
# ...

# %%
df2["Households"] = df2["Households"].astype("int64").copy()
df2
# Out:
# 0           1
# 1           2
# 2           2
# 3           2
# 4           3
#          ...
# 20635    4930
# 20636    5050
# 20637    5189
# 20638    5358
# 20639    6082
# Name: Households, Length: 20640, dtype: int64

# %%
df2["Population"] = df2["Population"].astype("int64").copy()
df2
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13          8.0             1.0    -122.50
# 1               2           8          6.0             2.0    -116.95
# 2               2           6          2.0             2.0    -117.79
# 3               2          28         49.0             7.0    -119.54
# 4               3           5         18.0             3.0    -114.62
# ...           ...         ...          ...             ...        ...
# 20635        4930        7431      18132.0          5419.0    -118.44
# 20636        5050       15507      32054.0          5290.0    -117.78
# 20637        5189       16122      37937.0          5471.0    -117.74
# 20638        5358       16305      39320.0          6210.0    -121.44
# 20639        6082       28566      32627.0          6445.0    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity  \
# ...

# %%
df2["Total_rooms"] = df2["Total_rooms"].astype("int64").copy()
df2
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13             1.0    -122.50
# 1               2           8            8             2.0    -116.95
# 2               2           6            6             2.0    -117.79
# 3               2          28           28             7.0    -119.54
# 4               3           5            5             3.0    -114.62
# ...           ...         ...          ...             ...        ...
# 20635        4930        7431         7431          5419.0    -118.44
# 20636        5050       15507        15507          5290.0    -117.78
# 20637        5189       16122        16122          5471.0    -117.74
# 20638        5358       16305        16305          6210.0    -121.44
# 20639        6082       28566        28566          6445.0    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity  \
# ...

# %%
df3 = df2.dropna().copy()
df3
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13             1.0    -122.50
# 1               2           8            8             2.0    -116.95
# 2               2           6            6             2.0    -117.79
# 3               2          28           28             7.0    -119.54
# 4               3           5            5             3.0    -114.62
# ...           ...         ...          ...             ...        ...
# 20635        4930        7431         7431          5419.0    -118.44
# 20636        5050       15507        15507          5290.0    -117.78
# 20637        5189       16122        16122          5471.0    -117.74
# 20638        5358       16305        16305          6210.0    -121.44
# 20639        6082       28566        28566          6445.0    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity  \
# ...

# %%
df3.drop_duplicates()
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13             1.0    -122.50
# 1               2           8            8             2.0    -116.95
# 2               2           6            6             2.0    -117.79
# 3               2          28           28             7.0    -119.54
# 4               3           5            5             3.0    -114.62
# ...           ...         ...          ...             ...        ...
# 20635        4930        7431         7431          5419.0    -118.44
# 20636        5050       15507        15507          5290.0    -117.78
# 20637        5189       16122        16122          5471.0    -117.74
# 20638        5358       16305        16305          6210.0    -121.44
# 20639        6082       28566        28566          6445.0    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity  \
# ...

# %%
df3
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13             1.0    -122.50
# 1               2           8            8             2.0    -116.95
# 2               2           6            6             2.0    -117.79
# 3               2          28           28             7.0    -119.54
# 4               3           5            5             3.0    -114.62
# ...           ...         ...          ...             ...        ...
# 20635        4930        7431         7431          5419.0    -118.44
# 20636        5050       15507        15507          5290.0    -117.78
# 20637        5189       16122        16122          5471.0    -117.74
# 20638        5358       16305        16305          6210.0    -121.44
# 20639        6082       28566        28566          6445.0    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity  \
# ...

# %%
df3.ffill()
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13             1.0    -122.50
# 1               2           8            8             2.0    -116.95
# 2               2           6            6             2.0    -117.79
# 3               2          28           28             7.0    -119.54
# 4               3           5            5             3.0    -114.62
# ...           ...         ...          ...             ...        ...
# 20635        4930        7431         7431          5419.0    -118.44
# 20636        5050       15507        15507          5290.0    -117.78
# 20637        5189       16122        16122          5471.0    -117.74
# 20638        5358       16305        16305          6210.0    -121.44
# 20639        6082       28566        28566          6445.0    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity  \
# ...

# %%
df3.isnull().sum()
# Out:
# Households                                                                   0
# Population                                                                   0
# Total_rooms                                                                  0
# Total_bedrooms                                                               0
# Longitude                                                                    0
# Latitude                                                                     0
# Median_income                                                                0
# Median_house_value                                                           0
# Ocean_proximity                                                              0
# (Households, Population, Total_rooms, Total_bedrooms, Median_house_value)    0
# dtype: int64

# %%
df3['Total_bedrooms'] = df3['Total_bedrooms'].astype("int64")
df3
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13               1    -122.50
# 1               2           8            8               2    -116.95
# 2               2           6            6               2    -117.79
# 3               2          28           28               7    -119.54
# 4               3           5            5               3    -114.62
# ...           ...         ...          ...             ...        ...
# 20635        4930        7431         7431            5419    -118.44
# 20636        5050       15507        15507            5290    -117.78
# 20637        5189       16122        16122            5471    -117.74
# 20638        5358       16305        16305            6210    -121.44
# 20639        6082       28566        28566            6445    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity  \
# ...

# %%
df3['Median_house_value'] = df3['Median_house_value'].astype("int64")
df3
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13               1    -122.50
# 1               2           8            8               2    -116.95
# 2               2           6            6               2    -117.79
# 3               2          28           28               7    -119.54
# 4               3           5            5               3    -114.62
# ...           ...         ...          ...             ...        ...
# 20635        4930        7431         7431            5419    -118.44
# 20636        5050       15507        15507            5290    -117.78
# 20637        5189       16122        16122            5471    -117.74
# 20638        5358       16305        16305            6210    -121.44
# 20639        6082       28566        28566            6445    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity  \
# ...

# %%
Final_data = df3.to_csv("Exact_housing_cleaned_data.csv",index=False)
Final_data

# %%
import pandas as pd

df = pd.read_csv("Exact_housing_cleaned_data.csv")

# Drop the last column by position
df = df.drop(df.columns[-1], axis=1)

# Save it back
df.to_csv("Exact_housing_cleaned_data.csv", index=False)

# %%
import pandas as pd 
df = pd.read_csv("Exact_housing_cleaned_data.csv")
df
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13               1    -122.50
# 1               2           8            8               2    -116.95
# 2               2           6            6               2    -117.79
# 3               2          28           28               7    -119.54
# 4               3           5            5               3    -114.62
# ...           ...         ...          ...             ...        ...
# 20428        4930        7431         7431            5419    -118.44
# 20429        5050       15507        15507            5290    -117.78
# 20430        5189       16122        16122            5471    -117.74
# 20431        5358       16305        16305            6210    -121.44
# 20432        6082       28566        28566            6445    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity
# ...

# %%
df.hist(bins = 10,figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'Households'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'Total_rooms'}>],
#        [<Axes: title={'center': 'Total_bedrooms'}>,
#         <Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'Latitude'}>],
#        [<Axes: title={'center': 'Median_income'}>,
#         <Axes: title={'center': 'Median_house_value'}>, <Axes: >]],
#       dtype=object)

# %%
import numpy as np

# %%
def shuffle_and_split(data, test_ratio):
    np.random.seed(42) # Set the seed for reproducibility
    shuffled_indices = np.random.permutation(len(data)) # This returns shuffled indices
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train, test = shuffle_and_split(df, 0.4)

# %%
train
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 13402         513        1884         1884             525    -118.46
# 13649         523        1243         1243             500    -122.24
# 12644         484        1525         1525             470    -117.87
# 15560         617        1595         1595             647    -120.99
# 3694          243         790          790             221    -122.09
# ...           ...         ...          ...             ...        ...
# 11284         440        1726         1726             419    -118.21
# 11964         461         921          921             490    -118.44
# 5390          287         670          670             353    -122.26
# 860           109         222          222             110    -118.82
# 15795         629        1363         1363             666    -117.32
#
#        Latitude  Median_income  Median_house_value Ocean_proximity
# ...

# %%
test
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 14278         551        1457         1457             561    -121.03
# 16224         658        1633         1633             668    -122.47
# 7646          342        1492         1492             323    -118.04
# 1402          150         473          473             160    -118.33
# 1328          146         406          406             141    -120.37
# ...           ...         ...          ...             ...        ...
# 5860          299         637          637             309    -121.06
# 184            28          75           75              29    -117.54
# 3711          244         560          560             270    -121.02
# 19191        1078        1986         1986            1116    -118.31
# 14826         577        1029         1029             593    -122.44
#
#        Latitude  Median_income  Median_house_value Ocean_proximity
# ...

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv("Exact_housing_cleaned_data.csv")
# Create income categories
df["income_cat"] = pd.cut(data["median_income"],
                             bins=[0, 1.5, 3.0, 4.5, 6.0, np.inf],
                             labels=[1, 2, 3, 4, 5])

# %%
df
# Out:
#        Households  Population  Total_rooms  Total_bedrooms  Longitude  \
# 0               1          13           13               1    -122.50
# 1               2           8            8               2    -116.95
# 2               2           6            6               2    -117.79
# 3               2          28           28               7    -119.54
# 4               3           5            5               3    -114.62
# ...           ...         ...          ...             ...        ...
# 20428        4930        7431         7431            5419    -118.44
# 20429        5050       15507        15507            5290    -117.78
# 20430        5189       16122        16122            5471    -117.74
# 20431        5358       16305        16305            6210    -121.44
# 20432        6082       28566        28566            6445    -121.79
#
#        Latitude  Median_income  Median_house_value Ocean_proximity income_cat
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit
 
# Assume income_cat is a column in the dataset created from median_income
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
 
for train_index, test_index in split.split(data, data["income_cat"]):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]

# %%
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
# ...

# %%
strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5241     -118.39     34.12                29.0       6447.0          1012.0
# 17352    -120.42     34.89                24.0       2020.0           307.0
# 3505     -118.45     34.25                36.0       1453.0           270.0
# 7777     -118.10     33.91                35.0       1653.0           325.0
# 14155    -117.07     32.77                38.0       3779.0           614.0
# ...          ...       ...                 ...          ...             ...
# 12182    -117.29     33.72                19.0       2248.0           427.0
# 7275     -118.24     33.99                33.0        885.0           294.0
# 17223    -119.72     34.44                43.0       1781.0           342.0
# 10786    -117.91     33.63                30.0       2071.0           412.0
# 3965     -118.56     34.19                36.0       2600.0           441.0
#
# ...

# %%
train_data = strat_train_set.to_csv("strat_train_set.csv")
train_data

# %%
test_data = strat_test_set.to_csv("strat_test_set.csv")
test_data

# %%
strat_train_set["income_cat"].hist(bins=8,
    edgecolor='black',   # or ec='black' — draws the border line around each bin
    linewidth=1.2,       # controls how thick that border line is
    color='skyblue'      # fill color of the bars (optional)
)
# Out:
# <Axes: >

# %%
strat_test_set["income_cat"].hist(bins=8,
    edgecolor='black',   # or ec='black' — draws the border line around each bin
    linewidth=1.2,       # controls how thick that border line is
    color='skyblue'      # fill color of the bars (optional)
)
# Out:
# <Axes: >
